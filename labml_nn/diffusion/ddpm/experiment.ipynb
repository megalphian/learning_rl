# %% [markdown]
# [![Github](https://img.shields.io/github/stars/labmlai/annotated_deep_learning_paper_implementations?style=social)](https://github.com/labmlai/annotated_deep_learning_paper_implementations)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/labmlai/annotated_deep_learning_paper_implementations/blob/master/labml_nn/diffusion/ddpm/experiment.ipynb)
#
# ## [Denoising Diffusion Probabilistic Models (DDPM)](https://nn.labml.ai/diffusion/ddpm/index.html)
#
# This notebook trains a DDPM based model on MNIST digits dataset.

# %% [markdown]
# ### Install the packages

# %%
# !pip install labml-nn --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 10.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.9/443.9 kB 28.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.0/131.0 kB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 69.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 37.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 105.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 95.6 MB/s eta 0:00:00
#   Building wheel for fairscale (pyproject.toml) ... done

# %% [markdown]
# ### Imports

# %%
import torch
import torch.nn as nn

from labml import experiment
from labml.configs import option
from labml_nn.diffusion.ddpm.experiment import Configs

# %% [markdown]
# ### Create an experiment

# %%
experiment.create(name="diffuse", writers={'screen'})

# %% [markdown]
# ### Configurations

# %%
configs = Configs()

# %% [markdown]
# Set experiment configurations and assign a configurations dictionary to override configurations

# %%
experiment.configs(configs, {
    'dataset': 'MNIST',
    'image_channels': 1,
    'epochs': 5,
})
# Out:
# <pre style="overflow-x: scroll;"></pre>

# %% [markdown]
# Initializ

# %%
configs.init()
# Out:
# <pre style="overflow-x: scroll;">Prepare device.device...
#   Prepare device.device_info<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	74.34ms</span>
# Prepare device.device<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	77.16ms</span>
# Prepare dataset<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	3,824.11ms</span>
# </pre>
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 18.1MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 495kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.52MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 10.5MB/s]

# %% [markdown]
# Set PyTorch models for loading and saving

# %%
experiment.add_pytorch_models({'eps_model': configs.eps_model})

# %% [markdown]
# ### Start the experiment and run the training loop.

# %%
# Start the experiment
with experiment.start():
    configs.run()
# Out:
# <pre style="overflow-x: scroll;"></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">       0:  </span></strong>Train:<span style="color: #C5C1B4">  ...</span><span style="color: #208FFB">  0ms  </span>  <span style="color: #208FFB">0ms</span><span style="color: #D160C4">  0:00m/  0:00m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">       1:  </span></strong>Train:<span style="color: #C5C1B4">  ...</span><span style="color: #208FFB">  0ms  </span> loss: <strong> 1.34797</strong>  <span style="color: #208FFB">0ms</span><span style="color: #D160C4">  0:00m/  0:00m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">       1:  </span></strong>Train:<span style="color: #C5C1B4">   0%</span><span style="color: #208FFB"> 938,964ms  </span> loss: <strong> 1.34797</strong>  <span style="color: #208FFB">938,964ms</span><span style="color: #D160C4">  0:00m/  1:18m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">       2:  </span></strong>Train:<span style="color: #C5C1B4">   0%</span><span style="color: #208FFB"> 1,175,374ms  </span> loss: <strong> 1.28450</strong>  <span style="color: #208FFB">1,175,374ms</span><span style="color: #D160C4">  0:00m/  1:37m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">       2:  </span></strong>Train:<span style="color: #C5C1B4">   0%</span><span style="color: #208FFB">   588,267ms  </span> loss: <strong> 1.28450</strong>  <span style="color: #208FFB">588,267ms</span><span style="color: #D160C4">  0:00m/  0:48m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">       3:  </span></strong>Train:<span style="color: #C5C1B4">   0%</span><span style="color: #208FFB">   708,460ms  </span> loss: <strong> 1.21189</strong>  <span style="color: #208FFB">708,460ms</span><span style="color: #D160C4">  0:00m/  0:58m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">       3:  </span></strong>Train:<span style="color: #C5C1B4">   0%</span><span style="color: #208FFB">   472,666ms  </span> loss: <strong> 1.21189</strong>  <span style="color: #208FFB">472,666ms</span><span style="color: #D160C4">  0:00m/  0:39m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">       4:  </span></strong>Train:<span style="color: #C5C1B4">   0%</span><span style="color: #208FFB">   553,894ms  </span> loss: <strong> 1.15850</strong>  <span style="color: #208FFB">553,894ms</span><span style="color: #D160C4">  0:00m/  0:46m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">       4:  </span></strong>Train:<span style="color: #C5C1B4">   0%</span><span style="color: #208FFB">   415,971ms  </span> loss: <strong> 1.15850</strong>  <span style="color: #208FFB">415,971ms</span><span style="color: #D160C4">  0:00m/  0:34m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">       5:  </span></strong>Train:<span style="color: #C5C1B4">   0%</span><span style="color: #208FFB">   476,310ms  </span> loss: <strong> 1.09443</strong>  <span style="color: #208FFB">476,310ms</span><span style="color: #D160C4">  0:00m/  0:39m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">       5:  </span></strong>Train:<span style="color: #C5C1B4">   0%</span><span style="color: #208FFB">   381,357ms  </span> loss: <strong> 1.09443</strong>  <span style="color: #208FFB">381,357ms</span><span style="color: #D160C4">  0:00m/  0:31m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">       6:  </span></strong>Train:<span style="color: #C5C1B4">   0%</span><span style="color: #208FFB">   538,048ms  </span> loss: <strong> 1.02890</strong>  <span style="color: #208FFB">538,048ms</span><span style="color: #D160C4">  0:00m/  0:44m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">       6:  </span></strong>Train:<span style="color: #C5C1B4">   0%</span><span style="color: #208FFB">   479,628ms  </span> loss: <strong> 1.02890</strong>  <span style="color: #208FFB">479,628ms</span><span style="color: #D160C4">  0:00m/  0:39m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">       7:  </span></strong>Train:<span style="color: #C5C1B4">   0%</span><span style="color: #208FFB">   511,967ms  </span> loss: <strong> 0.98614</strong>  <span style="color: #208FFB">511,967ms</span><span style="color: #D160C4">  0:00m/  0:42m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">       7:  </span></strong>Train:<span style="color: #C5C1B4">   0%</span><span style="color: #208FFB">   465,607ms  </span> loss: <strong> 0.98614</strong>  <span style="color: #208FFB">465,607ms</span><span style="color: #D160C4">  0:00m/  0:38m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">       8:  </span></strong>Train:<span style="color: #C5C1B4">   0%</span><span style="color: #208FFB">   493,416ms  </span> loss: <strong> 0.93426</strong>  <span style="color: #208FFB">493,416ms</span><span style="color: #D160C4">  0:00m/  0:41m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">       8:  </span></strong>Train:<span style="color: #C5C1B4">   0%</span><span style="color: #208FFB">   455,194ms  </span> loss: <strong> 0.93426</strong>  <span style="color: #208FFB">455,194ms</span><span style="color: #D160C4">  0:00m/  0:37m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">       9:  </span></strong>Train:<span style="color: #C5C1B4">   0%</span><span style="color: #208FFB">   479,777ms  </span> loss: <strong> 0.89426</strong>  <span style="color: #208FFB">479,777ms</span><span style="color: #D160C4">  0:00m/  0:39m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">       9:  </span></strong>Train:<span style="color: #C5C1B4">   0%</span><span style="color: #208FFB">   447,294ms  </span> loss: <strong> 0.89426</strong>  <span style="color: #208FFB">447,294ms</span><span style="color: #D160C4">  0:00m/  0:37m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      10:  </span></strong>Train:<span style="color: #C5C1B4">   0%</span><span style="color: #208FFB">   469,108ms  </span> loss: <strong> 0.83918</strong>  <span style="color: #208FFB">469,108ms</span><span style="color: #D160C4">  0:00m/  0:39m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      10:  </span></strong>Train:<span style="color: #C5C1B4">   1%</span><span style="color: #208FFB">   441,042ms  </span> loss: <strong> 0.83918</strong>  <span style="color: #208FFB">441,042ms</span><span style="color: #D160C4">  0:00m/  0:36m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      11:  </span></strong>Train:<span style="color: #C5C1B4">   1%</span><span style="color: #208FFB">   485,308ms  </span> loss: <strong>0.790769</strong>  <span style="color: #208FFB">485,308ms</span><span style="color: #D160C4">  0:00m/  0:40m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      11:  </span></strong>Train:<span style="color: #C5C1B4">   1%</span><span style="color: #208FFB">   462,907ms  </span> loss: <strong>0.790769</strong>  <span style="color: #208FFB">462,907ms</span><span style="color: #D160C4">  0:00m/  0:38m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      12:  </span></strong>Train:<span style="color: #C5C1B4">   1%</span><span style="color: #208FFB">   478,921ms  </span> loss: <strong>0.767727</strong>  <span style="color: #208FFB">478,921ms</span><span style="color: #D160C4">  0:00m/  0:39m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      12:  </span></strong>Train:<span style="color: #C5C1B4">   1%</span><span style="color: #208FFB">   458,926ms  </span> loss: <strong>0.767727</strong>  <span style="color: #208FFB">458,926ms</span><span style="color: #D160C4">  0:00m/  0:38m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      13:  </span></strong>Train:<span style="color: #C5C1B4">   1%</span><span style="color: #208FFB">   473,726ms  </span> loss: <strong>0.741557</strong>  <span style="color: #208FFB">473,726ms</span><span style="color: #D160C4">  0:00m/  0:39m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      13:  </span></strong>Train:<span style="color: #C5C1B4">   1%</span><span style="color: #208FFB">   455,663ms  </span> loss: <strong>0.741557</strong>  <span style="color: #208FFB">455,663ms</span><span style="color: #D160C4">  0:00m/  0:37m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      14:  </span></strong>Train:<span style="color: #C5C1B4">   1%</span><span style="color: #208FFB">   469,140ms  </span> loss: <strong>0.701781</strong>  <span style="color: #208FFB">469,140ms</span><span style="color: #D160C4">  0:00m/  0:38m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      14:  </span></strong>Train:<span style="color: #C5C1B4">   1%</span><span style="color: #208FFB">   452,697ms  </span> loss: <strong>0.701781</strong>  <span style="color: #208FFB">452,697ms</span><span style="color: #D160C4">  0:00m/  0:37m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      15:  </span></strong>Train:<span style="color: #C5C1B4">   1%</span><span style="color: #208FFB">   465,346ms  </span> loss: <strong>0.667996</strong>  <span style="color: #208FFB">465,346ms</span><span style="color: #D160C4">  0:00m/  0:38m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      15:  </span></strong>Train:<span style="color: #C5C1B4">   1%</span><span style="color: #208FFB">   450,269ms  </span> loss: <strong>0.667996</strong>  <span style="color: #208FFB">450,269ms</span><span style="color: #D160C4">  0:00m/  0:37m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      16:  </span></strong>Train:<span style="color: #C5C1B4">   1%</span><span style="color: #208FFB">   466,299ms  </span> loss: <strong>0.610036</strong>  <span style="color: #208FFB">466,299ms</span><span style="color: #D160C4">  0:00m/  0:38m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      16:  </span></strong>Train:<span style="color: #C5C1B4">   1%</span><span style="color: #208FFB">   453,132ms  </span> loss: <strong>0.610036</strong>  <span style="color: #208FFB">453,132ms</span><span style="color: #D160C4">  0:00m/  0:37m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      17:  </span></strong>Train:<span style="color: #C5C1B4">   1%</span><span style="color: #208FFB">   463,518ms  </span> loss: <strong>0.597473</strong>  <span style="color: #208FFB">463,518ms</span><span style="color: #D160C4">  0:00m/  0:38m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      17:  </span></strong>Train:<span style="color: #C5C1B4">   1%</span><span style="color: #208FFB">   451,284ms  </span> loss: <strong>0.597473</strong>  <span style="color: #208FFB">451,284ms</span><span style="color: #D160C4">  0:00m/  0:37m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      18:  </span></strong>Train:<span style="color: #C5C1B4">   1%</span><span style="color: #208FFB">   461,176ms  </span> loss: <strong>0.553620</strong>  <span style="color: #208FFB">461,176ms</span><span style="color: #D160C4">  0:00m/  0:38m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      18:  </span></strong>Train:<span style="color: #C5C1B4">   1%</span><span style="color: #208FFB">   449,755ms  </span> loss: <strong>0.553620</strong>  <span style="color: #208FFB">449,755ms</span><span style="color: #D160C4">  0:00m/  0:37m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      19:  </span></strong>Train:<span style="color: #C5C1B4">   1%</span><span style="color: #208FFB">   459,024ms  </span> loss: <strong>0.545210</strong>  <span style="color: #208FFB">459,024ms</span><span style="color: #D160C4">  0:00m/  0:38m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      19:  </span></strong>Train:<span style="color: #C5C1B4">   2%</span><span style="color: #208FFB">   448,310ms  </span> loss: <strong>0.545210</strong>  <span style="color: #208FFB">448,310ms</span><span style="color: #D160C4">  0:00m/  0:37m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      20:  </span></strong>Train:<span style="color: #C5C1B4">   2%</span><span style="color: #208FFB">   457,084ms  </span> loss: <strong>0.534445</strong>  <span style="color: #208FFB">457,084ms</span><span style="color: #D160C4">  0:00m/  0:37m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      20:  </span></strong>Train:<span style="color: #C5C1B4">   2%</span><span style="color: #208FFB">   447,006ms  </span> loss: <strong>0.534445</strong>  <span style="color: #208FFB">447,006ms</span><span style="color: #D160C4">  0:00m/  0:37m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      21:  </span></strong>Train:<span style="color: #C5C1B4">   2%</span><span style="color: #208FFB">   453,466ms  </span> loss: <strong>0.491621</strong>  <span style="color: #208FFB">453,466ms</span><span style="color: #D160C4">  0:00m/  0:37m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      21:  </span></strong>Train:<span style="color: #C5C1B4">   2%</span><span style="color: #208FFB">   444,256ms  </span> loss: <strong>0.491621</strong>  <span style="color: #208FFB">444,256ms</span><span style="color: #D160C4">  0:00m/  0:36m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      22:  </span></strong>Train:<span style="color: #C5C1B4">   2%</span><span style="color: #208FFB">   451,955ms  </span> loss: <strong>0.454473</strong>  <span style="color: #208FFB">451,955ms</span><span style="color: #D160C4">  0:00m/  0:37m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      22:  </span></strong>Train:<span style="color: #C5C1B4">   2%</span><span style="color: #208FFB">   443,231ms  </span> loss: <strong>0.454473</strong>  <span style="color: #208FFB">443,231ms</span><span style="color: #D160C4">  0:00m/  0:36m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      23:  </span></strong>Train:<span style="color: #C5C1B4">   2%</span><span style="color: #208FFB">   450,600ms  </span> loss: <strong>0.438223</strong>  <span style="color: #208FFB">450,600ms</span><span style="color: #D160C4">  0:00m/  0:37m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      23:  </span></strong>Train:<span style="color: #C5C1B4">   2%</span><span style="color: #208FFB">   442,313ms  </span> loss: <strong>0.438223</strong>  <span style="color: #208FFB">442,313ms</span><span style="color: #D160C4">  0:00m/  0:36m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      24:  </span></strong>Train:<span style="color: #C5C1B4">   2%</span><span style="color: #208FFB">   449,375ms  </span> loss: <strong>0.431516</strong>  <span style="color: #208FFB">449,375ms</span><span style="color: #D160C4">  0:00m/  0:37m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      25:  </span></strong>Train:<span style="color: #C5C1B4">   2%</span><span style="color: #208FFB">   448,892ms  </span> loss: <strong>0.387753</strong>  <span style="color: #208FFB">448,892ms</span><span style="color: #D160C4">  0:00m/  0:37m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      25:  </span></strong>Train:<span style="color: #C5C1B4">   2%</span><span style="color: #208FFB">   441,337ms  </span> loss: <strong>0.387753</strong>  <span style="color: #208FFB">441,337ms</span><span style="color: #D160C4">  0:00m/  0:36m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      26:  </span></strong>Train:<span style="color: #C5C1B4">   2%</span><span style="color: #208FFB">   444,632ms  </span> loss: <strong>0.387670</strong>  <span style="color: #208FFB">444,632ms</span><span style="color: #D160C4">  0:00m/  0:36m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      26:  </span></strong>Train:<span style="color: #C5C1B4">   2%</span><span style="color: #208FFB">   437,561ms  </span> loss: <strong>0.387670</strong>  <span style="color: #208FFB">437,561ms</span><span style="color: #D160C4">  0:00m/  0:36m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      27:  </span></strong>Train:<span style="color: #C5C1B4">   2%</span><span style="color: #208FFB">   443,753ms  </span> loss: <strong>0.382635</strong>  <span style="color: #208FFB">443,753ms</span><span style="color: #D160C4">  0:00m/  0:36m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      27:  </span></strong>Train:<span style="color: #C5C1B4">   2%</span><span style="color: #208FFB">   436,955ms  </span> loss: <strong>0.382635</strong>  <span style="color: #208FFB">436,955ms</span><span style="color: #D160C4">  0:00m/  0:36m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      28:  </span></strong>Train:<span style="color: #C5C1B4">   2%</span><span style="color: #208FFB">   442,893ms  </span> loss: <strong>0.371401</strong>  <span style="color: #208FFB">442,893ms</span><span style="color: #D160C4">  0:00m/  0:36m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      28:  </span></strong>Train:<span style="color: #C5C1B4">   2%</span><span style="color: #208FFB">   436,369ms  </span> loss: <strong>0.371401</strong>  <span style="color: #208FFB">436,369ms</span><span style="color: #D160C4">  0:00m/  0:36m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      29:  </span></strong>Train:<span style="color: #C5C1B4">   2%</span><span style="color: #208FFB">   442,078ms  </span> loss: <strong>0.345770</strong>  <span style="color: #208FFB">442,078ms</span><span style="color: #D160C4">  0:00m/  0:36m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      29:  </span></strong>Train:<span style="color: #C5C1B4">   3%</span><span style="color: #208FFB">   435,813ms  </span> loss: <strong>0.345770</strong>  <span style="color: #208FFB">435,813ms</span><span style="color: #D160C4">  0:00m/  0:36m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      30:  </span></strong>Train:<span style="color: #C5C1B4">   3%</span><span style="color: #208FFB">   441,340ms  </span> loss: <strong>0.334674</strong>  <span style="color: #208FFB">441,340ms</span><span style="color: #D160C4">  0:00m/  0:36m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      30:  </span></strong>Train:<span style="color: #C5C1B4">   3%</span><span style="color: #208FFB">   435,311ms  </span> loss: <strong>0.334674</strong>  <span style="color: #208FFB">435,311ms</span><span style="color: #D160C4">  0:00m/  0:36m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      31:  </span></strong>Train:<span style="color: #C5C1B4">   3%</span><span style="color: #208FFB">   437,131ms  </span> loss: <strong>0.369568</strong>  <span style="color: #208FFB">437,131ms</span><span style="color: #D160C4">  0:00m/  0:36m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      31:  </span></strong>Train:<span style="color: #C5C1B4">   3%</span><span style="color: #208FFB">   431,383ms  </span> loss: <strong>0.369568</strong>  <span style="color: #208FFB">431,383ms</span><span style="color: #D160C4">  0:00m/  0:35m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      32:  </span></strong>Train:<span style="color: #C5C1B4">   3%</span><span style="color: #208FFB">   436,504ms  </span> loss: <strong>0.314615</strong>  <span style="color: #208FFB">436,504ms</span><span style="color: #D160C4">  0:00m/  0:36m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      32:  </span></strong>Train:<span style="color: #C5C1B4">   3%</span><span style="color: #208FFB">   430,954ms  </span> loss: <strong>0.314615</strong>  <span style="color: #208FFB">430,954ms</span><span style="color: #D160C4">  0:00m/  0:35m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      33:  </span></strong>Train:<span style="color: #C5C1B4">   3%</span><span style="color: #208FFB">   435,969ms  </span> loss: <strong>0.321334</strong>  <span style="color: #208FFB">435,969ms</span><span style="color: #D160C4">  0:00m/  0:36m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      33:  </span></strong>Train:<span style="color: #C5C1B4">   3%</span><span style="color: #208FFB">   430,603ms  </span> loss: <strong>0.321334</strong>  <span style="color: #208FFB">430,603ms</span><span style="color: #D160C4">  0:00m/  0:35m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      34:  </span></strong>Train:<span style="color: #C5C1B4">   3%</span><span style="color: #208FFB">   435,418ms  </span> loss: <strong>0.292885</strong>  <span style="color: #208FFB">435,418ms</span><span style="color: #D160C4">  0:00m/  0:36m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      34:  </span></strong>Train:<span style="color: #C5C1B4">   3%</span><span style="color: #208FFB">   430,227ms  </span> loss: <strong>0.292885</strong>  <span style="color: #208FFB">430,227ms</span><span style="color: #D160C4">  0:00m/  0:35m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      35:  </span></strong>Train:<span style="color: #C5C1B4">   3%</span><span style="color: #208FFB">   434,962ms  </span> loss: <strong>0.286334</strong>  <span style="color: #208FFB">434,962ms</span><span style="color: #D160C4">  0:00m/  0:35m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">      35:  </span></strong>Train:<span style="color: #C5C1B4">   3%</span><span style="color: #208FFB">   429,928ms  </span> loss: <strong>0.286334</strong>  <span style="color: #208FFB">429,928ms</span><span style="color: #D160C4">  0:00m/  0:35m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# ...
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">     938:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   401,450ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <span style="color: #C5C1B4">0.034587</span>  <span style="color: #208FFB">455,717ms</span><span style="color: #D160C4">  0:07m/  0:30m  </span>
# <strong><span style="color: #DDB62B">   1,190:  </span></strong>Train:<span style="color: #C5C1B4">  26%</span><span style="color: #208FFB">   401,922ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <strong>0.027277</strong>  <span style="color: #208FFB">463,921ms</span><span style="color: #D160C4">  0:09m/  0:29m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">     938:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   401,450ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <span style="color: #C5C1B4">0.034587</span>  <span style="color: #208FFB">455,717ms</span><span style="color: #D160C4">  0:07m/  0:30m  </span>
# <strong><span style="color: #DDB62B">   1,191:  </span></strong>Train:<span style="color: #C5C1B4">  26%</span><span style="color: #208FFB">   402,552ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <strong>0.032750</strong>  <span style="color: #208FFB">463,921ms</span><span style="color: #D160C4">  0:09m/  0:29m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">     938:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   401,450ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <span style="color: #C5C1B4">0.034587</span>  <span style="color: #208FFB">455,717ms</span><span style="color: #D160C4">  0:07m/  0:30m  </span>
# <strong><span style="color: #DDB62B">   1,191:  </span></strong>Train:<span style="color: #C5C1B4">  26%</span><span style="color: #208FFB">   401,917ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <strong>0.032750</strong>  <span style="color: #208FFB">463,921ms</span><span style="color: #D160C4">  0:09m/  0:29m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">     938:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   401,450ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <span style="color: #C5C1B4">0.034587</span>  <span style="color: #208FFB">455,717ms</span><span style="color: #D160C4">  0:07m/  0:30m  </span>
# <strong><span style="color: #DDB62B">   1,192:  </span></strong>Train:<span style="color: #C5C1B4">  26%</span><span style="color: #208FFB">   402,545ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <strong>0.024058</strong>  <span style="color: #208FFB">463,921ms</span><span style="color: #D160C4">  0:09m/  0:29m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">     938:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   401,450ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <span style="color: #C5C1B4">0.034587</span>  <span style="color: #208FFB">455,717ms</span><span style="color: #D160C4">  0:07m/  0:30m  </span>
# <strong><span style="color: #DDB62B">   1,193:  </span></strong>Train:<span style="color: #C5C1B4">  27%</span><span style="color: #208FFB">   402,533ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <strong>0.025089</strong>  <span style="color: #208FFB">463,921ms</span><span style="color: #D160C4">  0:09m/  0:29m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">     938:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   401,450ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <span style="color: #C5C1B4">0.034587</span>  <span style="color: #208FFB">455,717ms</span><span style="color: #D160C4">  0:07m/  0:30m  </span>
# <strong><span style="color: #DDB62B">   1,193:  </span></strong>Train:<span style="color: #C5C1B4">  27%</span><span style="color: #208FFB">   401,903ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <strong>0.025089</strong>  <span style="color: #208FFB">463,921ms</span><span style="color: #D160C4">  0:09m/  0:29m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">     938:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   401,450ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <span style="color: #C5C1B4">0.034587</span>  <span style="color: #208FFB">455,717ms</span><span style="color: #D160C4">  0:07m/  0:30m  </span>
# <strong><span style="color: #DDB62B">   1,194:  </span></strong>Train:<span style="color: #C5C1B4">  27%</span><span style="color: #208FFB">   402,418ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <strong>0.040562</strong>  <span style="color: #208FFB">463,921ms</span><span style="color: #D160C4">  0:09m/  0:29m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">     938:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   401,450ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <span style="color: #C5C1B4">0.034587</span>  <span style="color: #208FFB">455,717ms</span><span style="color: #D160C4">  0:07m/  0:30m  </span>
# <strong><span style="color: #DDB62B">   1,194:  </span></strong>Train:<span style="color: #C5C1B4">  27%</span><span style="color: #208FFB">   401,790ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <strong>0.040562</strong>  <span style="color: #208FFB">463,921ms</span><span style="color: #D160C4">  0:09m/  0:29m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">     938:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   401,450ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <span style="color: #C5C1B4">0.034587</span>  <span style="color: #208FFB">455,717ms</span><span style="color: #D160C4">  0:07m/  0:30m  </span>
# <strong><span style="color: #DDB62B">   1,195:  </span></strong>Train:<span style="color: #C5C1B4">  27%</span><span style="color: #208FFB">   402,413ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <strong>0.023554</strong>  <span style="color: #208FFB">463,921ms</span><span style="color: #D160C4">  0:09m/  0:29m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">     938:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   401,450ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <span style="color: #C5C1B4">0.034587</span>  <span style="color: #208FFB">455,717ms</span><span style="color: #D160C4">  0:07m/  0:30m  </span>
# <strong><span style="color: #DDB62B">   1,195:  </span></strong>Train:<span style="color: #C5C1B4">  27%</span><span style="color: #208FFB">   401,787ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <strong>0.023554</strong>  <span style="color: #208FFB">463,921ms</span><span style="color: #D160C4">  0:09m/  0:29m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">     938:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   401,450ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <span style="color: #C5C1B4">0.034587</span>  <span style="color: #208FFB">455,717ms</span><span style="color: #D160C4">  0:07m/  0:30m  </span>
# <strong><span style="color: #DDB62B">   1,196:  </span></strong>Train:<span style="color: #C5C1B4">  27%</span><span style="color: #208FFB">   402,410ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <strong>0.026777</strong>  <span style="color: #208FFB">463,921ms</span><span style="color: #D160C4">  0:09m/  0:29m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">     938:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   401,450ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <span style="color: #C5C1B4">0.034587</span>  <span style="color: #208FFB">455,717ms</span><span style="color: #D160C4">  0:07m/  0:30m  </span>
# <strong><span style="color: #DDB62B">   1,196:  </span></strong>Train:<span style="color: #C5C1B4">  27%</span><span style="color: #208FFB">   401,788ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <strong>0.026777</strong>  <span style="color: #208FFB">463,921ms</span><span style="color: #D160C4">  0:09m/  0:29m  </span></pre>
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">bffb492c383611f0bc160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">     938:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   401,450ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,266ms  </span> loss: <span style="color: #C5C1B4">0.034587</span>  <span style="color: #208FFB">455,717ms</span><span style="color: #D160C4">  0:07m/  0:30m  </span>
# <strong><span style="color: #DDB62B">   1,876:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   401,184ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,172ms  </span> loss: <span style="color: #C5C1B4">0.019371</span>  <span style="color: #208FFB">463,921ms</span><span style="color: #D160C4">  0:15m/  0:23m  </span>
# <strong><span style="color: #DDB62B">   2,545:  </span></strong>Train:<span style="color: #C5C1B4">  71%</span><span style="color: #208FFB">   401,844ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 54,172ms  </span> loss: <strong>0.014336</strong>  <span style="color: #208FFB">463,466ms</span><span style="color: #D160C4">  0:20m/  0:18m  </span></pre>
